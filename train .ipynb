# %%
import sys
# !{sys.executable} -m pip install scikit-learn
import pandas as pd
from sklearn.model_selection import train_test_split

trials_df = pd.read_csv('TRIALS_DATABASE_READY.csv') 
validation, rest = train_test_split(
      trials_df,
      test_size=0.95,
      stratify=trials_df['specialty'],
      random_state=42
)
test, train = train_test_split(
      rest,
      test_size=0.9,
      stratify=rest['specialty'],
      random_state=42
)
validation.to_csv('validation_trials.csv', index=False)
test.to_csv('test_trials.csv', index=False)
train.to_csv('train_trials.csv', index=False)
print(len(validation))
print(len(test))
print(len(train))
print(len(trials_df))
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# WARNING: You are using pip version 21.2.4; however, version 26.0.1 is available.
# You should consider upgrading via the '/Library/Developer/CommandLineTools/usr/bin/python3 -m pip install --upgrade pip' command.
# 50
# 95
# 855
# 1000
